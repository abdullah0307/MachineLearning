# %%
import cv2
import face_recognition

img = cv2.imread("RegisteredFaces/abdullah.jpg")
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
boxes=face_recognition.face_locations(rgb)
print(boxes)
# Out:
# [(50, 112, 94, 69)]

# %%
known_image = face_recognition.load_image_file("RegisteredFaces/abdullah.jpg")

# %%
enc = face_recognition.face_encodings(known_image)[0]

# %%
import matplotlib.pyplot as plt
plt.imshow(known_image)

# %%
cv2.imshow("", img)
cv2.waitKey(0)
# Out:
# -1

# %%
if len(boxes)>0:
    enc=face_recognition.face_encodings(rgb,boxes)[0]
    matches = face_recognition.compare_faces(known_enc,enc,tolerance=0.55)
    print(matches)
